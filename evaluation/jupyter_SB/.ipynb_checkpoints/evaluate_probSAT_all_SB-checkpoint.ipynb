# %% [markdown]
# # Evaluation of data collected with probSAT w.r.t. Johnson SB distribution
#
# We tested probSAT with 55 hidden solution instances with $n \in \{50, 100, 150, 200, 300, 800\}$ variables.
#
# The concrete instances can be seen below.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#
# Load all necessary modules
#

# Module for "Unix style pathname pattern expansion" 
# and "Miscellaneous operating system interfaces"
import glob
import os

# Modules for data analysis, plotting, etc.
import pandas as pd
import numpy as np
from scipy.stats import probplot
from matplotlib import pyplot as plt
from scipy import stats
import seaborn as sns

# Load our own modules for analysis of ecdfs, survival functions, 
# confidence intervals, etc. and the respective plotting. 
# The corresponding files can be found in ./evaluation_SB/jupyter.
from empirical import *
from plots import *

# %%
# Specify the base path of this experiment series.
# The base path is refined by folders incidating the number of variables.
path = '../../experiments/csvs_probSAT'
filters = ['n50', 'n100', 'n150', 'n200', 'n300', 'n800']

# %%
# List all instances under consideration.
instances = []
for filter in filters:
    instances += glob.glob(os.path.join(path, f'*{filter}*.csv'))

instances
# Out:
# ['../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed440213416.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed3184935164.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed2746317214.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed1051802513.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed107420370.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed478163328.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed3163119786.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed599310826.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed958682847.csv',
#  '../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed1181241944.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2342331445.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2536146026.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed127978095.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed373399427.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed136505588.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2906402158.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed3831882065.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed3181143732.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed402418011.csv',
#  '../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed1812140442.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed999270937.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed854001194.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2170484434.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2410529191.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2585650757.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed3012167821.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed113971124.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2791232394.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed939042956.csv',
#  '../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed3075280818.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed2530876845.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed27911968.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3476477324.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3733616460.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed2340505847.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed946785249.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3259052812.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1929338155.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1801823909.csv',
#  '../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1194819985.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed618188454.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1228722199.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2884700867.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1588610338.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1986560904.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2999771048.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed3275703685.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2990260697.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed165578902.csv',
#  '../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed4120618906.csv',
#  '../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed2487936524.csv',
#  '../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed263749128.csv',
#  '../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed4045445228.csv',
#  '../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed210108687.csv',
#  '../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed1618881351.csv']

# %%
# Count the instances.
len(instances)
# Out:
# 55

# %% [markdown]
# ## Visual inspection
#
# In this section, we are going to inspect the data in a visual manner.
#
# A detailed description can be found in the paper. For easier reference, we next provide a short guide.
#
#
# ### log-plot ecdf vs. cdf; ecdf vs. cdf; log-plot e-survival vs. survial (from left to right)
#
# * **Left plot:** The left tail, i. e., the probabilities for very small values, can be checked visually by plotting the ecdf and fitted cdf with both axes logarithmically scaled. Thereby, the probabilities for extreme events (in this case, especially easy instances) can be measured accurately. The $x$-axis in such graphs corresponds to the time (in flips) until a solution is found, and the $y$-axis corresponds to the probability that a solution is found until that time. In red we depict the empirically collected data; blue is the fitted distribution.
#
# * **Middle plot:** Plot of the ecdf and the fitted cdf on the same graph.
#
# * **Right plot:** Lastly, the probabilities for particularly hard instances should also be checked. Any mistakes in this area could lead to underestimating the likelihood of encountering an exceptionally hard instance. For analyses of this type, the survival function $S$ is a useful tool; if $F$ is the cdf, $S(x) := 1 − F (x)$. Therefore, the survival function’s value $S(x)$ represents the probability that an instance is (on average) harder than $x$ in our case. If we plot the empirical survival function ($1 − \hat{F}_n (x)$) and the fitted survival function together on a graph with logarithmically scaled axes, we can easily detect errors in the right tail.

# %%
# Select the number of instances to interate over...
N = len(instances)

# ... and iterate over all instances to generate the plots.
for index in range(N):
    #
    # Selection of a concrete instance and name printing
    #
    name = instances[index]
    
    print("*" * (len(name) + len(str(index)) + 3))
    print(index, ":", name)
    print("*" * (len(name) + len(str(index)) + 3))   

    #
    # Manipulate the corresponding data frame:
    # We are only interested in the flip-values, not in the runtime, or seed used.
    #
    df = pd.read_csv(name, index_col=[0,1])
    df.drop(index=['seed', 'runtime'], level=1, inplace=True)

    # Checks if any values are nan.
    if df.isnull().values.any():
        print("There is a nan-value. This was not supposed to happen.")
        
    # Next, we are going to calculate $\mathsf{mean}_{S} (F^{(i)})$,
    # i.e., the mean number of flips required to solve instance $F^{(i)}$ with solver $S$.
    # This then is the hardness distribution we are going to analyze.    
    means = df.mean(axis=1)
    means = np.sort(means)  
        
    #
    # Print the plots with location parameter
    #    
    
    # Scipy can be used to fit a location parameter. 
    # In practise, however, this does not work properly.
    # Thus, we use our own method `SB_minimize_nnlf` 
    # that can be found in the `empirical` package.
    # This method must be provided with the data object `means`, 
    # a lower bound for the location parameter, here `0.0`,
    # and an upper bound for the location parameter, here `means[0]-0.0001`.
    # This method then yields a location parameter maximizing the likelihood.
    m = SB_minimize_nnlf(means, 0.0, means[0]-0.0001)
    means_SB = means - m 

    # Next, we fit a three-parametric Johnson SB distribution 
    # (with forced location parameter zero). Note that means = means - m. 
    # Note that fitting a three-parametric lognormal distribution to 
    # original_data - m is the same as fitting 
    # a four-parametric lognormal distribution to the original_data.
    # Afterwards, we can use our own location parameter.
    a, b, loc, scale = johnsonsb.fit(means_SB, floc=0) # NEW!!!

    print(f"Johnson SB parameters: a {a}, b {b}, location {m}, scale {scale}")
    print(f"Cheng parametrization: a {m}, b {scale+m}, gamma {a}, delta {b}")

    rv_SB = johnsonsb(a, b, loc, scale)
    
    plot_and_compare_cdf(means_SB, rv_SB, suptitle='Johnson SB', plot_confidence=True)

    plt.show(block=False)
    
    print("\n")
# Out:
# ***********************************************************************
# 0 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed440213416.csv
# ***********************************************************************
# Johnson SB parameters: a 9.56491448262252, b 1.7016680889810187, location 881.0224049555405, scale 1795692.8480307353
# Cheng parametrization: a 881.0224049555405, b 1796573.8704356907, gamma 9.56491448262252, delta 1.7016680889810187
# ************************************************************************
# 1 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed3184935164.csv
# ************************************************************************
# Johnson SB parameters: a 11.873705755160163, b 2.4846329537666456, location 226.8622084294498, scale 114563.95196109495
# Cheng parametrization: a 226.8622084294498, b 114790.8141695244, gamma 11.873705755160163, delta 2.4846329537666456
# ************************************************************************
# 2 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed2746317214.csv
# ************************************************************************
# Johnson SB parameters: a 2.8539173519538323, b 4.200668154289769, location 40.7655086324011, scale 538.728733548396
# Cheng parametrization: a 40.7655086324011, b 579.4942421807971, gamma 2.8539173519538323, delta 4.200668154289769
# ************************************************************************
# 3 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed1051802513.csv
# ************************************************************************
# Johnson SB parameters: a 8.87034338176598, b 3.5400719694882983, location 77.12001197753747, scale 4741.638524484893
# Cheng parametrization: a 77.12001197753747, b 4818.758536462431, gamma 8.87034338176598, delta 3.5400719694882983
# ***********************************************************************
# 4 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed107420370.csv
# ***********************************************************************
# Johnson SB parameters: a 1.6193998221235053, b 3.446857380140262, location 4.815728268744007e-06, scale 1711.6265267721064
# Cheng parametrization: a 4.815728268744007e-06, b 1711.6265315878347, gamma 1.6193998221235053, delta 3.446857380140262
# ***********************************************************************
# 5 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed478163328.csv
# ***********************************************************************
# Johnson SB parameters: a 2.3753859490769207, b 4.152518054755635, location 38.22596246347784, scale 583.9254051036531
# Cheng parametrization: a 38.22596246347784, b 622.1513675671309, gamma 2.3753859490769207, delta 4.152518054755635
# ************************************************************************
# 6 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed3163119786.csv
# ************************************************************************
# Johnson SB parameters: a 6.565279998651247, b 4.3904304766326785, location 3.553428797424419, scale 2109.389974583316
# Cheng parametrization: a 3.553428797424419, b 2112.94340338074, gamma 6.565279998651247, delta 4.3904304766326785
# ***********************************************************************
# 7 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed599310826.csv
# ***********************************************************************
# Johnson SB parameters: a 15.333612594708626, b 5.71735195626745, location 36.20164005300786, scale 1369.443732150406
# Cheng parametrization: a 36.20164005300786, b 1405.645372203414, gamma 15.333612594708626, delta 5.71735195626745
# ***********************************************************************
# 8 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed958682847.csv
# ***********************************************************************
# Johnson SB parameters: a 4.162363800072748, b 1.9289665856024771, location 5.5107673505664806e-06, scale 56062.792318515254
# Cheng parametrization: a 5.5107673505664806e-06, b 56062.79232402602, gamma 4.162363800072748, delta 1.9289665856024771
# ************************************************************************
# 9 : ../../experiments/csvs_probSAT/gen_n50_m213_k3SAT_seed1181241944.csv
# ************************************************************************
# Johnson SB parameters: a 2.800861121945421, b 2.1082074706306106, location 195.89792773277966, scale 1184.4017170110405
# Cheng parametrization: a 195.89792773277966, b 1380.2996447438202, gamma 2.800861121945421, delta 2.1082074706306106
# **************************************************************************
# 10 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2342331445.csv
# **************************************************************************
# Johnson SB parameters: a 12.868321613480761, b 2.443532890810737, location 1398.9729025912718, scale 1038124.9124620715
# Cheng parametrization: a 1398.9729025912718, b 1039523.8853646627, gamma 12.868321613480761, delta 2.443532890810737
# **************************************************************************
# 11 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2536146026.csv
# **************************************************************************
# Johnson SB parameters: a 5.590678154422587, b 2.4630192528644033, location 681.4380738542103, scale 18599.74744773625
# Cheng parametrization: a 681.4380738542103, b 19281.185521590458, gamma 5.590678154422587, delta 2.4630192528644033
# *************************************************************************
# 12 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed127978095.csv
# *************************************************************************
# Johnson SB parameters: a 6.39999225661448, b 2.8044249285041207, location 6.431490789691579e-06, scale 35674.61413000879
# Cheng parametrization: a 6.431490789691579e-06, b 35674.61413644028, gamma 6.39999225661448, delta 2.8044249285041207
# *************************************************************************
# 13 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed373399427.csv
# *************************************************************************
# Johnson SB parameters: a 17.038069902712962, b 5.413872836269148, location 1331.6848627991183, scale 94373.47657423356
# Cheng parametrization: a 1331.6848627991183, b 95705.16143703267, gamma 17.038069902712962, delta 5.413872836269148
# *************************************************************************
# 14 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed136505588.csv
# *************************************************************************
# Johnson SB parameters: a 10.590631924278819, b 5.65485713227128, location 5.1306651366013676e-06, scale 10250.475854883105
# Cheng parametrization: a 5.1306651366013676e-06, b 10250.47586001377, gamma 10.590631924278819, delta 5.65485713227128
# **************************************************************************
# 15 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed2906402158.csv
# **************************************************************************
# Johnson SB parameters: a 8.245118531355775, b 4.8776516695114305, location 185.40683540733107, scale 2738.4882537408807
# Cheng parametrization: a 185.40683540733107, b 2923.895089148212, gamma 8.245118531355775, delta 4.8776516695114305
# **************************************************************************
# 16 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed3831882065.csv
# **************************************************************************
# Johnson SB parameters: a 8.709979652464035, b 1.8678258478965697, location 816.6304447638624, scale 427907.084032109
# Cheng parametrization: a 816.6304447638624, b 428723.7144768729, gamma 8.709979652464035, delta 1.8678258478965697
# **************************************************************************
# 17 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed3181143732.csv
# **************************************************************************
# Johnson SB parameters: a 7.843766378607569, b 6.095532177596791, location 99.21118211826736, scale 2187.680877183937
# Cheng parametrization: a 99.21118211826736, b 2286.8920593022044, gamma 7.843766378607569, delta 6.095532177596791
# *************************************************************************
# 18 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed402418011.csv
# *************************************************************************
# Johnson SB parameters: a 16.889751757411297, b 4.750806133940863, location 3250.3589670164442, scale 323595.71974951634
# Cheng parametrization: a 3250.3589670164442, b 326846.0787165328, gamma 16.889751757411297, delta 4.750806133940863
# **************************************************************************
# 19 : ../../experiments/csvs_probSAT/gen_n100_m427_k3SAT_seed1812140442.csv
# **************************************************************************
# Johnson SB parameters: a 3.10629847384598, b 4.663921345376645, location 224.68334918676678, scale 1300.8593409435232
# Cheng parametrization: a 224.68334918676678, b 1525.5426901302899, gamma 3.10629847384598, delta 4.663921345376645
# *************************************************************************
# 20 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed999270937.csv
# *************************************************************************
# Johnson SB parameters: a 13.185573433860384, b 3.1043208917286673, location 591903.923292369, scale 359156980.25046134
# Cheng parametrization: a 591903.923292369, b 359748884.17375374, gamma 13.185573433860384, delta 3.1043208917286673
# *************************************************************************
# 21 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed854001194.csv
# *************************************************************************
# Johnson SB parameters: a 15.891397291849046, b 7.307454428291543, location 564.6404185877025, scale 15391.791910276828
# Cheng parametrization: a 564.6404185877025, b 15956.43232886453, gamma 15.891397291849046, delta 7.307454428291543
# **************************************************************************
# 22 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2170484434.csv
# **************************************************************************
# Johnson SB parameters: a 14.653855037440053, b 6.197324593979847, location 1031.4219373529595, scale 32770.63318790663
# Cheng parametrization: a 1031.4219373529595, b 33802.05512525959, gamma 14.653855037440053, delta 6.197324593979847
# **************************************************************************
# 23 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2410529191.csv
# **************************************************************************
# Johnson SB parameters: a 16.30428653200157, b 7.563911632010511, location 447.0663343243136, scale 17139.84165448811
# Cheng parametrization: a 447.0663343243136, b 17586.907988812425, gamma 16.30428653200157, delta 7.563911632010511
# **************************************************************************
# 24 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2585650757.csv
# **************************************************************************
# Johnson SB parameters: a 13.421883108745007, b 3.41878179109014, location 7733.368841164696, scale 985315.7695240271
# Cheng parametrization: a 7733.368841164696, b 993049.1383651919, gamma 13.421883108745007, delta 3.41878179109014
# **************************************************************************
# 25 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed3012167821.csv
# **************************************************************************
# Johnson SB parameters: a 16.55054455985654, b 5.952633348430949, location 2077.5923259479973, scale 116889.11179432218
# Cheng parametrization: a 2077.5923259479973, b 118966.70412027018, gamma 16.55054455985654, delta 5.952633348430949
# *************************************************************************
# 26 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed113971124.csv
# *************************************************************************
# Johnson SB parameters: a 16.274969864038802, b 5.660828974439752, location 1823.2248672649753, scale 64564.70841706281
# Cheng parametrization: a 1823.2248672649753, b 66387.93328432778, gamma 16.274969864038802, delta 5.660828974439752
# **************************************************************************
# 27 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed2791232394.csv
# **************************************************************************
# Johnson SB parameters: a 16.661066490362238, b 6.258811468275788, location 765.7779350042437, scale 35101.36023731179
# Cheng parametrization: a 765.7779350042437, b 35867.13817231603, gamma 16.661066490362238, delta 6.258811468275788
# *************************************************************************
# 28 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed939042956.csv
# *************************************************************************
# Johnson SB parameters: a 15.720172007266644, b 4.935558347498889, location 1350.8346849910267, scale 171441.06934062653
# Cheng parametrization: a 1350.8346849910267, b 172791.90402561755, gamma 15.720172007266644, delta 4.935558347498889
# **************************************************************************
# 29 : ../../experiments/csvs_probSAT/gen_n150_m640_k3SAT_seed3075280818.csv
# **************************************************************************
# Johnson SB parameters: a 4.9625089466817105, b 4.521954763282489, location 1331.3975631067344, scale 7417.05212221715
# Cheng parametrization: a 1331.3975631067344, b 8748.449685323885, gamma 4.9625089466817105, delta 4.521954763282489
# **************************************************************************
# 30 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed2530876845.csv
# **************************************************************************
# Johnson SB parameters: a 13.649357577509127, b 4.00570856715812, location 10318.86032779296, scale 949828.5016366924
# Cheng parametrization: a 10318.86032779296, b 960147.3619644854, gamma 13.649357577509127, delta 4.00570856715812
# ************************************************************************
# 31 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed27911968.csv
# ************************************************************************
# Johnson SB parameters: a 4.149673664787127, b 4.953273957285047, location 2075.750105810393, scale 12378.294710501315
# Cheng parametrization: a 2075.750105810393, b 14454.044816311709, gamma 4.149673664787127, delta 4.953273957285047
# **************************************************************************
# 32 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3476477324.csv
# **************************************************************************
# Johnson SB parameters: a 12.520533200138729, b 2.95598115166875, location 976680.6106577995, scale 303737819.8940245
# Cheng parametrization: a 976680.6106577995, b 304714500.5046823, gamma 12.520533200138729, delta 2.95598115166875
# **************************************************************************
# 33 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3733616460.csv
# **************************************************************************
# Johnson SB parameters: a 14.540471820635837, b 3.4827346301691486, location 41813.73460504462, scale 8368905.462543795
# Cheng parametrization: a 41813.73460504462, b 8410719.197148839, gamma 14.540471820635837, delta 3.4827346301691486
# **************************************************************************
# 34 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed2340505847.csv
# **************************************************************************
# Johnson SB parameters: a 14.859524047838768, b 5.010192172963819, location 6116.8161870197655, scale 224150.84143441927
# Cheng parametrization: a 6116.8161870197655, b 230267.65762143902, gamma 14.859524047838768, delta 5.010192172963819
# *************************************************************************
# 35 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed946785249.csv
# *************************************************************************
# Johnson SB parameters: a 14.32916829701147, b 4.812662496766455, location 4986.33305125862, scale 220287.40952731244
# Cheng parametrization: a 4986.33305125862, b 225273.74257857105, gamma 14.32916829701147, delta 4.812662496766455
# **************************************************************************
# 36 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed3259052812.csv
# **************************************************************************
# Johnson SB parameters: a 12.202363986110612, b 2.5012782191235168, location 243964.01014719545, scale 78847376.02238426
# Cheng parametrization: a 243964.01014719545, b 79091340.03253146, gamma 12.202363986110612, delta 2.5012782191235168
# **************************************************************************
# 37 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1929338155.csv
# **************************************************************************
# Johnson SB parameters: a 12.243752490371055, b 2.4675617085696784, location 202291.74114922425, scale 98902862.59951428
# Cheng parametrization: a 202291.74114922425, b 99105154.3406635, gamma 12.243752490371055, delta 2.4675617085696784
# **************************************************************************
# 38 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1801823909.csv
# **************************************************************************
# Johnson SB parameters: a 15.07403959667485, b 8.226188884939063, location 576.708639923482, scale 18823.16532332085
# Cheng parametrization: a 576.708639923482, b 19399.873963244332, gamma 15.07403959667485, delta 8.226188884939063
# **************************************************************************
# 39 : ../../experiments/csvs_probSAT/gen_n200_m853_k3SAT_seed1194819985.csv
# **************************************************************************
# Johnson SB parameters: a 16.258271546902108, b 6.465847415322719, location 599.3396889817798, scale 344889.17087041645
# Cheng parametrization: a 599.3396889817798, b 345488.5105593982, gamma 16.258271546902108, delta 6.465847415322719
# **************************************************************************
# 40 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed618188454.csv
# **************************************************************************
# Johnson SB parameters: a 12.994420927298293, b 4.019217555327415, location 26200.34198489841, scale 1045475.9214965487
# Cheng parametrization: a 26200.34198489841, b 1071676.263481447, gamma 12.994420927298293, delta 4.019217555327415
# ***************************************************************************
# 41 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1228722199.csv
# ***************************************************************************
# Johnson SB parameters: a 15.21642728556133, b 5.048594147542168, location 11853.978734675791, scale 534363.0059026494
# Cheng parametrization: a 11853.978734675791, b 546216.9846373252, gamma 15.21642728556133, delta 5.048594147542168
# ***************************************************************************
# 42 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2884700867.csv
# ***************************************************************************
# Johnson SB parameters: a 13.86576869903147, b 3.1603235809661907, location 39781.67692557742, scale 5063896.9292925075
# Cheng parametrization: a 39781.67692557742, b 5103678.606218085, gamma 13.86576869903147, delta 3.1603235809661907
# ***************************************************************************
# 43 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1588610338.csv
# ***************************************************************************
# Johnson SB parameters: a 3.189545803429703, b 3.873341540331956, location 4087.396718828301, scale 13944.416649525634
# Cheng parametrization: a 4087.396718828301, b 18031.813368353934, gamma 3.189545803429703, delta 3.873341540331956
# ***************************************************************************
# 44 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed1986560904.csv
# ***************************************************************************
# Johnson SB parameters: a 14.667740966390795, b 4.384906413768153, location 11779.127063455297, scale 465864.7242496486
# Cheng parametrization: a 11779.127063455297, b 477643.8513131039, gamma 14.667740966390795, delta 4.384906413768153
# ***************************************************************************
# 45 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2999771048.csv
# ***************************************************************************
# Johnson SB parameters: a 13.814376876617363, b 4.001186973768216, location 44290.44230603022, scale 4703970.307770243
# Cheng parametrization: a 44290.44230603022, b 4748260.750076273, gamma 13.814376876617363, delta 4.001186973768216
# ***************************************************************************
# 46 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed3275703685.csv
# ***************************************************************************
# Johnson SB parameters: a 12.525319077112897, b 2.8027959817450787, location 79112.85162825244, scale 10282346.875466585
# Cheng parametrization: a 79112.85162825244, b 10361459.727094838, gamma 12.525319077112897, delta 2.8027959817450787
# ***************************************************************************
# 47 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed2990260697.csv
# ***************************************************************************
# Johnson SB parameters: a 15.624324350122205, b 7.141356219330479, location 2282.072474450627, scale 71622.61893932437
# Cheng parametrization: a 2282.072474450627, b 73904.691413775, gamma 15.624324350122205, delta 7.141356219330479
# **************************************************************************
# 48 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed165578902.csv
# **************************************************************************
# Johnson SB parameters: a 13.242302300870584, b 3.4210809676985594, location 125439.16740934871, scale 82471507.71543872
# Cheng parametrization: a 125439.16740934871, b 82596946.88284807, gamma 13.242302300870584, delta 3.4210809676985594
# ***************************************************************************
# 49 : ../../experiments/csvs_probSAT/gen_n300_m1280_k3SAT_seed4120618906.csv
# ***************************************************************************
# Johnson SB parameters: a 13.13253279538419, b 2.9013976160349655, location 288482.3380565769, scale 136375155.415009
# Cheng parametrization: a 288482.3380565769, b 136663637.75306556, gamma 13.13253279538419, delta 2.9013976160349655
# ***************************************************************************
# 50 : ../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed2487936524.csv
# ***************************************************************************
# Johnson SB parameters: a 15.873011795871722, b 5.408216160204075, location 69736.07620037386, scale 4159819.548060729
# Cheng parametrization: a 69736.07620037386, b 4229555.624261103, gamma 15.873011795871722, delta 5.408216160204075
# **************************************************************************
# 51 : ../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed263749128.csv
# **************************************************************************
# There is a nan-value. This was not supposed to happen.
# Johnson SB parameters: a 9.915393894488538, b 1.9546536187002657, location 61655144.92634257, scale 70080450618.30609
# Cheng parametrization: a 61655144.92634257, b 70142105763.23244, gamma 9.915393894488538, delta 1.9546536187002657
# ***************************************************************************
# 52 : ../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed4045445228.csv
# ***************************************************************************
# Johnson SB parameters: a 10.72240572783301, b 2.2816103896628457, location 41409276.44287534, scale 29932071221.90496
# Cheng parametrization: a 41409276.44287534, b 29973480498.347836, gamma 10.72240572783301, delta 2.2816103896628457
# **************************************************************************
# 53 : ../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed210108687.csv
# **************************************************************************
# Johnson SB parameters: a 10.5979667829315, b 2.463547286852421, location 3130200.055194593, scale 1645887086.9418917
# Cheng parametrization: a 3130200.055194593, b 1649017286.9970863, gamma 10.5979667829315, delta 2.463547286852421
# ***************************************************************************
# 54 : ../../experiments/csvs_probSAT/gen_n800_m3414_k3SAT_seed1618881351.csv
# ***************************************************************************
# Johnson SB parameters: a 11.24815313085675, b 2.258220990942915, location 6034179.120334426, scale 2986642555.984848
# Cheng parametrization: a 6034179.120334426, b 2992676735.1051826, gamma 11.24815313085675, delta 2.258220990942915

# %% [markdown]
# ## Statistical Tests
#
# As described in the paper, we use a statistical test to check the goodness-of-fit.
#
# (The p-values obtained were calculated seperately and can be found in `./evaluation/evaluate_SB/all_tests.csv` for all solver and instance combinations. The reason for this is that it takes several hours to compute these values because of the bootstrapping.)

# %%
# Use the instance list as a selector for the correct rows in the `all_tests.csv` file.
selector = [path.split('../../experiments/')[1] for path in instances]
selector

# Extract the relevant rows from the data frame.
file = '../evaluate_SB/all_tests.csv'
df = pd.read_csv(file, index_col=False)
df = df[df['instance'].isin(selector)]

# Sort the entries to match the order of the diagrams above.
df['instance'] = pd.Categorical(
    df['instance'], 
    categories=selector, 
    ordered=True
)
df.sort_values('instance', inplace=True)

# Show the instance name without path
df['instance'] = df['instance'].map(lambda name: name.split("/")[-1].split(".csv")[0])

# Mark entries where the tests failes
stars = np.where((df['p_orig']<0.05) & (df['p_new']<0.05), 'rejected', ' ')
df.loc[:, 'rejected'] = stars.tolist()

# Add the index we used
index = list(range(len(instances)))
df['index'] = index

# Change order of columns s.th. index is the first one
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

df
# Out:
#      index     type                             instance    p_orig  p_new  \
# 206      0  probSAT     gen_n50_m213_k3SAT_seed440213416  0.547663   0.60
# 210      1  probSAT    gen_n50_m213_k3SAT_seed3184935164  0.310153   0.40
# 215      2  probSAT    gen_n50_m213_k3SAT_seed2746317214  0.313278   0.32
# 222      3  probSAT    gen_n50_m213_k3SAT_seed1051802513  0.938788   0.96
# 223      4  probSAT     gen_n50_m213_k3SAT_seed107420370  0.170618   0.25
# 224      5  probSAT     gen_n50_m213_k3SAT_seed478163328  0.351835   0.28
# 244      6  probSAT    gen_n50_m213_k3SAT_seed3163119786  0.645298   0.71
# 248      7  probSAT     gen_n50_m213_k3SAT_seed599310826  0.572524   0.62
# 252      8  probSAT     gen_n50_m213_k3SAT_seed958682847  0.027253   0.05
# 259      9  probSAT    gen_n50_m213_k3SAT_seed1181241944  0.631719   0.69
# 205     10  probSAT   gen_n100_m427_k3SAT_seed2342331445  0.161926   0.22
# 207     11  probSAT   gen_n100_m427_k3SAT_seed2536146026  0.256535   0.22
# 221     12  probSAT    gen_n100_m427_k3SAT_seed127978095  0.469069   0.47
# 225     13  probSAT    gen_n100_m427_k3SAT_seed373399427  0.155605   0.18
# 227     14  probSAT    gen_n100_m427_k3SAT_seed136505588  0.048547   0.06
# 229     15  probSAT   gen_n100_m427_k3SAT_seed2906402158  0.268000   0.25
# 230     16  probSAT   gen_n100_m427_k3SAT_seed3831882065  0.268000   0.20
# 238     17  probSAT   gen_n100_m427_k3SAT_seed3181143732  0.752494   0.79
# 243     18  probSAT    gen_n100_m427_k3SAT_seed402418011  0.188910   0.15
# 246     19  probSAT   gen_n100_m427_k3SAT_seed1812140442  0.416242   0.37
# 208     20  probSAT    gen_n150_m640_k3SAT_seed999270937  0.023267   0.00
# 218     21  probSAT    gen_n150_m640_k3SAT_seed854001194  0.294750   0.24
# 219     22  probSAT   gen_n150_m640_k3SAT_seed2170484434  0.013273   0.00
# 228     23  probSAT   gen_n150_m640_k3SAT_seed2410529191  0.476191   0.50
# 233     24  probSAT   gen_n150_m640_k3SAT_seed2585650757  0.875428   0.89
# 236     25  probSAT   gen_n150_m640_k3SAT_seed3012167821  0.840130   0.83
# 241     26  probSAT    gen_n150_m640_k3SAT_seed113971124  0.265108   0.28
# 254     27  probSAT   gen_n150_m640_k3SAT_seed2791232394  0.971525   0.97
# 256     28  probSAT    gen_n150_m640_k3SAT_seed939042956  0.375144   0.36
# 257     29  probSAT   gen_n150_m640_k3SAT_seed3075280818  0.469069   0.53
# 209     30  probSAT   gen_n200_m853_k3SAT_seed2530876845  0.022805   0.01
# 211     31  probSAT     gen_n200_m853_k3SAT_seed27911968  0.237131   0.30
# 212     32  probSAT   gen_n200_m853_k3SAT_seed3476477324  0.205901   0.23
# 220     33  probSAT   gen_n200_m853_k3SAT_seed3733616460  0.395531   0.45
# 226     34  probSAT   gen_n200_m853_k3SAT_seed2340505847  0.804194   0.80
# 237     35  probSAT    gen_n200_m853_k3SAT_seed946785249  0.671937   0.63
# 242     36  probSAT   gen_n200_m853_k3SAT_seed3259052812  0.355131   0.35
# 247     37  probSAT   gen_n200_m853_k3SAT_seed1929338155  0.198507   0.19
# 250     38  probSAT   gen_n200_m853_k3SAT_seed1801823909  0.472628   0.51
# 253     39  probSAT   gen_n200_m853_k3SAT_seed1194819985  0.522661   0.46
# 213     40  probSAT   gen_n300_m1280_k3SAT_seed618188454  0.229079   0.24
# 216     41  probSAT  gen_n300_m1280_k3SAT_seed1228722199  0.451328   0.46
# 232     42  probSAT  gen_n300_m1280_k3SAT_seed2884700867  0.023267   0.00
# 235     43  probSAT  gen_n300_m1280_k3SAT_seed1588610338  0.345280   0.36
# 239     44  probSAT  gen_n300_m1280_k3SAT_seed1986560904  0.381900   0.36
# 240     45  probSAT  gen_n300_m1280_k3SAT_seed2999771048  0.533387   0.56
# 245     46  probSAT  gen_n300_m1280_k3SAT_seed3275703685  0.568985   0.54
# 249     47  probSAT  gen_n300_m1280_k3SAT_seed2990260697  0.005742   0.00
# 251     48  probSAT   gen_n300_m1280_k3SAT_seed165578902  0.042052   0.02
# 255     49  probSAT  gen_n300_m1280_k3SAT_seed4120618906  0.145447   0.19
# 214     50  probSAT  gen_n800_m3414_k3SAT_seed2487936524  0.392109   0.33
# 217     51  probSAT   gen_n800_m3414_k3SAT_seed263749128  0.015415   0.00
# 231     52  probSAT  gen_n800_m3414_k3SAT_seed4045445228  0.631719   0.62
# 234     53  probSAT   gen_n800_m3414_k3SAT_seed210108687  0.032413   0.06
# 258     54  probSAT  gen_n800_m3414_k3SAT_seed1618881351  0.423208   0.44
#
#      rejected
# 206
# 210
# 215
# 222
# 223
# 224
# 244
# 248
# 252
# 259
# 205
# 207
# 221
# 225
# 227
# 229
# 230
# 238
# 243
# 246
# 208  rejected
# 218
# 219  rejected
# 228
# 233
# 236
# 241
# 254
# 256
# 257
# 209  rejected
# 211
# 212
# 220
# 226
# 237
# 242
# 247
# 250
# 253
# 213
# 216
# 232  rejected
# 235
# 239
# 240
# 245
# 249  rejected
# 251  rejected
# 255
# 214
# 217  rejected
# 231
# 234
# 258
