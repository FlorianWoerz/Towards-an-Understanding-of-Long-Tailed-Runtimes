# %% [markdown]
# # Evaluation of data collected with SRWA and coloring instances
#
# We tested SRWA with 32 coloring instances with 50 vertices.
#
# The concrete instances can be seen below.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Preliminaries

# %%
#
# Load all necessary modules
#

# Module for "Unix style pathname pattern expansion" 
# and "Miscellaneous operating system interfaces"
import glob
import os

# Modules for data analysis, plotting, etc.
import pandas as pd
import numpy as np
from scipy.stats import probplot
from matplotlib import pyplot as plt
from scipy import stats
import seaborn as sns

# Load our own modules for analysis of ecdfs, survival functions, 
# confidence intervals, etc. and the respective plotting. 
# The corresponding files can be found in ./evaluation/jupyter.
from empirical import *
from plots import *

# %%
# Specify the base path of this experiment series.
# The base path is refined by folders incidating the number of variables.
# For SRWA + hidden instances, we used instances with n \in {50, 100} variables.
base_path = '../../experiments/csvs_coloring'
filter = 'n50'

# %%
# List all instances under consideration.
instance_path = os.path.join(base_path, filter)
instances = glob.glob(instance_path + '/*.csv')
instances
# Out:
# ['../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed18_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed72_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed36_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed42_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed75_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed5_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed20_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed17_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed69_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed70_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed25_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed93_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed34_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed61_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed58_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed26_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed11_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed37_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed55_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed32_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed50_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed84_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed95_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed6_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed23_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed89_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed1_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed86_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed65_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed74_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed4_cnfgen.csv',
#  '../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed97_cnfgen.csv']

# %% [markdown]
# ## Visual inspection
#
# In this section, we are going to inspect the data in a visual manner.
#
# A detailed description can be found in the paper. For easier reference, we next provide a short guide.
#
#
# ### log-plot ecdf vs. cdf; ecdf vs. cdf; log-plot e-survival vs. survial (from left to right)
#
# * **Left plot:** The left tail, i. e., the probabilities for very small values, can be checked visually by plotting the ecdf and fitted cdf with both axes logarithmically scaled. Thereby, the probabilities for extreme events (in this case, especially easy instances) can be measured accurately. The $x$-axis in such graphs corresponds to the time (in flips) until a solution is found, and the $y$-axis corresponds to the probability that a solution is found until that time. In red we depict the empirically collected data; blue is the fitted distribution.
#
# * **Middle plot:** Plot of the ecdf and the fitted cdf on the same graph.
#
# * **Right plot:** Lastly, the probabilities for particularly hard instances should also be checked. Any mistakes in this area could lead to underestimating the likelihood of encountering an exceptionally hard instance. For analyses of this type, the survival function $S$ is a useful tool; if $F$ is the cdf, $S(x) := 1 − F (x)$. Therefore, the survival function’s value $S(x)$ represents the probability that an instance is (on average) harder than $x$ in our case. If we plot the empirical survival function ($1 − \hat{F}_n (x)$) and the fitted survival function together on a graph with logarithmically scaled axes, we can easily detect errors in the right tail.

# %%
# Select the number of instances to interate over...
N = len(instances)

# ... and iterate over all instances to generate the plots.
for index in range(N):
    #
    # Selection of a concrete instance and name printing
    #
    name = instances[index]
    
    print("*" * (len(name) + len(str(index)) + 3))
    print(index, ":", name)
    print("*" * (len(name) + len(str(index)) + 3))   

    #
    # Manipulate the corresponding data frame:
    # We are only interested in the flip-values, not in the runtime, or seed used.
    #
    df = pd.read_csv(name, index_col=[0,1])
    df.drop(index=['seed', 'runtime'], level=1, inplace=True)

    # Checks if any values are nan.
    if df.isnull().values.any():
        print("There is a nan-value. This was not supposed to happen.")
        
    # Next, we are going to calculate $\mathsf{mean}_{S} (F^{(i)})$,
    # i.e., the mean number of flips required to solve instance $F^{(i)}$ with solver $S$.
    # This then is the hardness distribution we are going to analyze.    
    means = df.mean(axis=1)
    means = np.sort(means)  
        
    #
    # Print the plots with location parameter
    #    
    
    # Scipy can be used to fit a location parameter. 
    # In practise, however, this does not work properly.
    # Thus, we use our own method `SB_minimize_nnlf` 
    # that can be found in the `empirical` package.
    # This method must be provided with the data object `means`, 
    # a lower bound for the location parameter, here `0.0`,
    # and an upper bound for the location parameter, here `means[0]-0.0001`.
    # This method then yields a location parameter maximizing the likelihood.
    m = SB_minimize_nnlf(means, 0.0, means[0]-0.0001)
    means_SB = means - m 

    # Next, we fit a three-parametric Johnson SB distribution 
    # (with forced location parameter zero). Note that means = means - m. 
    # Note that fitting a three-parametric lognormal distribution to 
    # original_data - m is the same as fitting 
    # a four-parametric lognormal distribution to the original_data.
    # Afterwards, we can use our own location parameter.
    a, b, loc, scale = johnsonsb.fit(means_SB, floc=0) # NEW!!!

    print(f"Johnson SB parameters: a {a}, b {b}, location {m}, scale {scale}")
    print(f"Cheng parametrization: a {m}, b {scale+m}, gamma {a}, delta {b}")

    rv_SB = johnsonsb(a, b, loc, scale)
    
    plot_and_compare_cdf(means_SB, rv_SB, suptitle='Johnson SB', plot_confidence=True)

    plt.show(block=False)
    
    print("\n")
# Out:
# *******************************************************************************************
# 0 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed18_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 12.316562628085915, b 7.102576278184012, location 15762.670603336453, scale 6714753.779930505
# Cheng parametrization: a 15762.670603336453, b 6730516.450533842, gamma 12.316562628085915, delta 7.102576278184012
# *******************************************************************************************
# 1 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed72_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 14.195516828500402, b 5.4678610394720835, location 4169829.835228752, scale 454453591.6528425
# Cheng parametrization: a 4169829.835228752, b 458623421.48807126, gamma 14.195516828500402, delta 5.4678610394720835
# *******************************************************************************************
# 2 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed36_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 16.122844633530832, b 6.843220606249389, location 1168575.9279610119, scale 193959343.15332782
# Cheng parametrization: a 1168575.9279610119, b 195127919.08128884, gamma 16.122844633530832, delta 6.843220606249389
# *******************************************************************************************
# 3 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed42_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 15.278538201848074, b 7.122226493764609, location 33087.18072187378, scale 17843821.99653944
# Cheng parametrization: a 33087.18072187378, b 17876909.177261315, gamma 15.278538201848074, delta 7.122226493764609
# *******************************************************************************************
# 4 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed75_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 15.982767465629195, b 6.604451936277194, location 123606.46743262636, scale 30682578.120087385
# Cheng parametrization: a 123606.46743262636, b 30806184.58752001, gamma 15.982767465629195, delta 6.604451936277194
# ******************************************************************************************
# 5 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed5_cnfgen.csv
# ******************************************************************************************
# Johnson SB parameters: a 5.739246151925407, b 3.967714144869205, location 3817462.072450136, scale 55760012.0854328
# Cheng parametrization: a 3817462.072450136, b 59577474.15788294, gamma 5.739246151925407, delta 3.967714144869205
# *******************************************************************************************
# 6 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed20_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 13.730728331892195, b 6.314275099828784, location 92502.23693979906, scale 8182625.5217898525
# Cheng parametrization: a 92502.23693979906, b 8275127.758729652, gamma 13.730728331892195, delta 6.314275099828784
# *******************************************************************************************
# 7 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed17_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 5.235044029151998, b 4.531089891131403, location 166694.4390348961, scale 2152067.96601778
# Cheng parametrization: a 166694.4390348961, b 2318762.405052676, gamma 5.235044029151998, delta 4.531089891131403
# *******************************************************************************************
# 8 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed69_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 14.623975913021162, b 5.889222559020503, location 1094843.9711726415, scale 150628077.80051082
# Cheng parametrization: a 1094843.9711726415, b 151722921.77168345, gamma 14.623975913021162, delta 5.889222559020503
# *******************************************************************************************
# 9 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed70_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 13.835899288897838, b 7.503210550151545, location 473.06557293991443, scale 120801.88181599703
# Cheng parametrization: a 473.06557293991443, b 121274.94738893694, gamma 13.835899288897838, delta 7.503210550151545
# ********************************************************************************************
# 10 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed25_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 15.351916413490084, b 6.641409793296948, location 1469398.3944984097, scale 241176391.80198693
# Cheng parametrization: a 1469398.3944984097, b 242645790.19648534, gamma 15.351916413490084, delta 6.641409793296948
# ********************************************************************************************
# 11 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed93_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 12.874053859739508, b 5.1523008405419475, location 1566382.0367633775, scale 72527111.19810787
# Cheng parametrization: a 1566382.0367633775, b 74093493.23487124, gamma 12.874053859739508, delta 5.1523008405419475
# ********************************************************************************************
# 12 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed34_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 13.882792745036078, b 6.340159538848614, location 293947.65889786475, scale 14863606.012803655
# Cheng parametrization: a 293947.65889786475, b 15157553.67170152, gamma 13.882792745036078, delta 6.340159538848614
# ********************************************************************************************
# 13 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed61_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 14.18489223459136, b 6.06724883206633, location 6962260.760979724, scale 595611011.1375482
# Cheng parametrization: a 6962260.760979724, b 602573271.898528, gamma 14.18489223459136, delta 6.06724883206633
# ********************************************************************************************
# 14 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed58_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 6.013027777340686, b 5.192762583901162, location 72305.28365280513, scale 1289977.587166386
# Cheng parametrization: a 72305.28365280513, b 1362282.870819191, gamma 6.013027777340686, delta 5.192762583901162
# ********************************************************************************************
# 15 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed26_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 3.511368097483415, b 3.9729052845370054, location 186686.17756236639, scale 1340367.3622852864
# Cheng parametrization: a 186686.17756236639, b 1527053.539847653, gamma 3.511368097483415, delta 3.9729052845370054
# ********************************************************************************************
# 16 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed11_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 14.519543340241107, b 6.184770996918452, location 195989.9198080073, scale 13433122.518741317
# Cheng parametrization: a 195989.9198080073, b 13629112.438549325, gamma 14.519543340241107, delta 6.184770996918452
# ********************************************************************************************
# 17 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed37_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 10.738796739955927, b 6.652890945050007, location 15418.86894476814, scale 1073419.0782052442
# Cheng parametrization: a 15418.86894476814, b 1088837.9471500122, gamma 10.738796739955927, delta 6.652890945050007
# ********************************************************************************************
# 18 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed55_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 12.797007378806109, b 6.26874441857296, location 28958.10871974155, scale 1687218.804321072
# Cheng parametrization: a 28958.10871974155, b 1716176.9130408135, gamma 12.797007378806109, delta 6.26874441857296
# ********************************************************************************************
# 19 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed32_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 13.748336073957763, b 6.850459690558685, location 365593.3332388697, scale 131048121.87925169
# Cheng parametrization: a 365593.3332388697, b 131413715.21249056, gamma 13.748336073957763, delta 6.850459690558685
# ********************************************************************************************
# 20 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed50_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 15.235036284665895, b 7.28231203802159, location 2518.8218545289983, scale 14490210.798322499
# Cheng parametrization: a 2518.8218545289983, b 14492729.620177029, gamma 15.235036284665895, delta 7.28231203802159
# ********************************************************************************************
# 21 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed84_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 4.925987320896846, b 4.825458197428347, location 8433.512355223214, scale 96580.2909864992
# Cheng parametrization: a 8433.512355223214, b 105013.8033417224, gamma 4.925987320896846, delta 4.825458197428347
# ********************************************************************************************
# 22 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed95_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 14.397482785414809, b 6.010487182876751, location 151595.50292235872, scale 10506064.1892303
# Cheng parametrization: a 151595.50292235872, b 10657659.692152658, gamma 14.397482785414809, delta 6.010487182876751
# *******************************************************************************************
# 23 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed6_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 15.05740191871449, b 5.901590158582863, location 875018.7497250548, scale 172312222.54080194
# Cheng parametrization: a 875018.7497250548, b 173187241.290527, gamma 15.05740191871449, delta 5.901590158582863
# ********************************************************************************************
# 24 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed23_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 4.23230531534003, b 3.8989292006564966, location 933706.8095594349, scale 9360658.222528428
# Cheng parametrization: a 933706.8095594349, b 10294365.032087862, gamma 4.23230531534003, delta 3.8989292006564966
# ********************************************************************************************
# 25 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed89_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 16.534291474870514, b 6.153079749145981, location 61797.7652912434, scale 6042546.83637503
# Cheng parametrization: a 61797.7652912434, b 6104344.601666274, gamma 16.534291474870514, delta 6.153079749145981
# *******************************************************************************************
# 26 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed1_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 15.16680889473615, b 6.632186965995118, location 39823.78184044519, scale 4093265.1508401018
# Cheng parametrization: a 39823.78184044519, b 4133088.932680547, gamma 15.16680889473615, delta 6.632186965995118
# ********************************************************************************************
# 27 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed86_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 14.541521365919358, b 6.3564290336369, location 188892.34280785642, scale 9985223.753171697
# Cheng parametrization: a 188892.34280785642, b 10174116.095979555, gamma 14.541521365919358, delta 6.3564290336369
# ********************************************************************************************
# 28 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed65_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 15.240558603280668, b 7.068152576788069, location 46824.74314613326, scale 22173582.54139118
# Cheng parametrization: a 46824.74314613326, b 22220407.28453731, gamma 15.240558603280668, delta 7.068152576788069
# ********************************************************************************************
# 29 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed74_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 5.942597070001028, b 4.29295236407987, location 135557.5852503021, scale 1431225.6124469927
# Cheng parametrization: a 135557.5852503021, b 1566783.1976972949, gamma 5.942597070001028, delta 4.29295236407987
# *******************************************************************************************
# 30 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed4_cnfgen.csv
# *******************************************************************************************
# Johnson SB parameters: a 10.709130115735672, b 6.735061284184868, location 4.3088454151618166e-05, scale 11925901.202653732
# Cheng parametrization: a 4.3088454151618166e-05, b 11925901.20269682, gamma 10.709130115735672, delta 6.735061284184868
# ********************************************************************************************
# 31 : ../../experiments/csvs_coloring/n50/three_color_gnp_50vertices_p0.092_seed97_cnfgen.csv
# ********************************************************************************************
# Johnson SB parameters: a 13.919917949708985, b 6.566903522258038, location 15664.219504456605, scale 1114136.4951255107
# Cheng parametrization: a 15664.219504456605, b 1129800.7146299672, gamma 13.919917949708985, delta 6.566903522258038

# %% [markdown]
# ## Statistical Tests
#
# As described in the paper, we use a statistical test to check the goodness-of-fit.
#
# (The p-values obtained were calculated seperately and can be found in `./evaluation/evaluate_SB/all_tests.csv` for all solver and instance combinations. The reason for this is that it takes several hours to compute these values because of the bootstrapping.)

# %%
# Use the instance list as a selector for the correct rows in the `all_tests.csv` file.
selector = [path.split('../../experiments/')[1] for path in instances]
selector

# Extract the relevant rows from the data frame.
file = '../evaluate_SB/all_tests.csv'
df = pd.read_csv(file, index_col=False)
df = df[df['instance'].isin(selector)]

# Sort the entries to match the order of the diagrams above.
df['instance'] = pd.Categorical(
    df['instance'], 
    categories=selector, 
    ordered=True
)
df.sort_values('instance', inplace=True)

# Show the instance name without path
df['instance'] = df['instance'].map(lambda name: name.split("/")[-1].split(".csv")[0])

# Mark entries where the tests failes
stars = np.where((df['p_orig']<0.05) & (df['p_new']<0.05), 'rejected', ' ')
df.loc[:, 'rejected'] = stars.tolist()

# Add the index we used
index = list(range(len(instances)))
df['index'] = index

# Change order of columns s.th. index is the first one
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

df
# Out:
#     index  type                                         instance    p_orig  \
# 0       0  SRWA  three_color_gnp_50vertices_p0.092_seed18_cnfgen  0.003900
# 1       1  SRWA  three_color_gnp_50vertices_p0.092_seed72_cnfgen  0.056804
# 2       2  SRWA  three_color_gnp_50vertices_p0.092_seed36_cnfgen  0.804194
# 3       3  SRWA  three_color_gnp_50vertices_p0.092_seed42_cnfgen  0.769534
# 4       4  SRWA  three_color_gnp_50vertices_p0.092_seed75_cnfgen  0.873511
# 5       5  SRWA   three_color_gnp_50vertices_p0.092_seed5_cnfgen  0.903422
# 6       6  SRWA  three_color_gnp_50vertices_p0.092_seed20_cnfgen  0.624872
# 7       7  SRWA  three_color_gnp_50vertices_p0.092_seed17_cnfgen  0.796479
# 8       8  SRWA  three_color_gnp_50vertices_p0.092_seed69_cnfgen  0.568985
# 9       9  SRWA  three_color_gnp_50vertices_p0.092_seed70_cnfgen  0.895207
# 10     10  SRWA  three_color_gnp_50vertices_p0.092_seed25_cnfgen  0.412770
# 11     11  SRWA  three_color_gnp_50vertices_p0.092_seed93_cnfgen  0.755378
# 12     12  SRWA  three_color_gnp_50vertices_p0.092_seed34_cnfgen  0.607602
# 13     13  SRWA  three_color_gnp_50vertices_p0.092_seed61_cnfgen  0.288695
# 14     14  SRWA  three_color_gnp_50vertices_p0.092_seed58_cnfgen  0.989422
# 15     15  SRWA  three_color_gnp_50vertices_p0.092_seed26_cnfgen  0.465513
# 16     16  SRWA  three_color_gnp_50vertices_p0.092_seed11_cnfgen  0.930426
# 17     17  SRWA  three_color_gnp_50vertices_p0.092_seed37_cnfgen  0.307043
# 18     18  SRWA  three_color_gnp_50vertices_p0.092_seed55_cnfgen  0.691403
# 19     19  SRWA  three_color_gnp_50vertices_p0.092_seed32_cnfgen  0.678477
# 20     20  SRWA  three_color_gnp_50vertices_p0.092_seed50_cnfgen  0.133874
# 21     21  SRWA  three_color_gnp_50vertices_p0.092_seed84_cnfgen  0.853249
# 22     22  SRWA  three_color_gnp_50vertices_p0.092_seed95_cnfgen  0.203418
# 23     23  SRWA   three_color_gnp_50vertices_p0.092_seed6_cnfgen  0.547663
# 24     24  SRWA  three_color_gnp_50vertices_p0.092_seed23_cnfgen  0.635129
# 25     25  SRWA  three_color_gnp_50vertices_p0.092_seed89_cnfgen  0.168417
# 26     26  SRWA   three_color_gnp_50vertices_p0.092_seed1_cnfgen  0.799070
# 27     27  SRWA  three_color_gnp_50vertices_p0.092_seed86_cnfgen  0.087079
# 28     28  SRWA  three_color_gnp_50vertices_p0.092_seed65_cnfgen  0.934109
# 29     29  SRWA  three_color_gnp_50vertices_p0.092_seed74_cnfgen  0.385294
# 30     30  SRWA   three_color_gnp_50vertices_p0.092_seed4_cnfgen  0.074231
# 31     31  SRWA  three_color_gnp_50vertices_p0.092_seed97_cnfgen  0.998540
#
#     p_new  rejected
# 0    0.00  rejected
# 1    0.05
# 2    0.76
# 3    0.73
# 4    0.86
# 5    0.90
# 6    0.50
# 7    0.83
# 8    0.59
# 9    0.87
# 10   0.40
# 11   0.68
# 12   0.56
# 13   0.24
# 14   1.00
# 15   0.44
# 16   0.89
# 17   0.27
# 18   0.65
# 19   0.72
# 20   0.15
# 21   0.81
# 22   0.25
# 23   0.51
# 24   0.55
# 25   0.20
# 26   0.87
# 27   0.09
# 28   0.96
# 29   0.30
# 30   0.05
# 31   1.00
