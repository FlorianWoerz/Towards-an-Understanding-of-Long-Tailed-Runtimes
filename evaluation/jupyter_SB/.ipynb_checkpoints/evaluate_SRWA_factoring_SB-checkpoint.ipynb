# %% [markdown]
# # Evaluation of data collected with SRWA and hidden instances w.r.t. Johnson SB distribution
#
# We tested SRWA with 33 factoring instances from the interval $\{128, \dots , 256\}$.
#
# The concrete instances can be seen below.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## Preliminaries

# %%
#
# Load all necessary modules
#

# Module for "Unix style pathname pattern expansion" 
# and "Miscellaneous operating system interfaces"
import glob
import os

# Modules for data analysis, plotting, etc.
import pandas as pd
import numpy as np
from scipy.stats import probplot
from matplotlib import pyplot as plt
from scipy import stats
import seaborn as sns

# Load our own modules for analysis of ecdfs, survival functions, 
# confidence intervals, etc. and the respective plotting. 
# The corresponding files can be found in ./evaluation_SB/jupyter.
from empirical import *
from plots import *

# %%
# Specify the base path of this experiment series.
# The base path is refined by folders incidating the number of variables.
# For SRWA on factoring instances, we used only instances with n=146 variables.
base_path = '../../experiments/csvs_factoring'
filter = 'n146'

# %%
# List all instances under consideration.
instance_path = os.path.join(base_path, filter)
instances = glob.glob(instance_path + '/*.csv')
instances
# Out:
# ['../../experiments/csvs_factoring/n146/factor_seed5748459585663058586_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed6407482039203833974_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed2982912307005450882_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed8811850223749535532_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed7097131721234373659_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4387742571411731982_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed5193781827104823697_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4334240155445824856_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed8975071664002667775_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed7766064159550827863_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4336985158444443336_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed1708947292090439414_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed8317433272424785325_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4036333616503776890_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3276133011702650363_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed5418786872277260423_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed2578686028862375251_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4058983540373604130_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3159482308856066977_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3382895559700741256_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed6693062327952490429_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed1440291489233318306_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4781976350427207108_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed7560604667037574268_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3924672928578402759_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3451321871718893577_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3101904018255215309_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3844218716737448635_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3358904958101883040_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed6875843913543011199_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed4017489231758302290_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed6130376794532478281_minn128_maxn256_composite.csv',
#  '../../experiments/csvs_factoring/n146/factor_seed3506515261408426867_minn128_maxn256_composite.csv']

# %% [markdown]
# ## Visual inspection
#
# In this section, we are going to inspect the data in a visual manner.
#
# A detailed description can be found in the paper. For easier reference, we next provide a short guide.
#
#
# ### log-plot ecdf vs. cdf; ecdf vs. cdf; log-plot e-survival vs. survial (from left to right)
#
# * **Left plot:** The left tail, i. e., the probabilities for very small values, can be checked visually by plotting the ecdf and fitted cdf with both axes logarithmically scaled. Thereby, the probabilities for extreme events (in this case, especially easy instances) can be measured accurately. The $x$-axis in such graphs corresponds to the time (in flips) until a solution is found, and the $y$-axis corresponds to the probability that a solution is found until that time. In red we depict the empirically collected data; blue is the fitted distribution.
#
# * **Middle plot:** Plot of the ecdf and the fitted cdf on the same graph.
#
# * **Right plot:** Lastly, the probabilities for particularly hard instances should also be checked. Any mistakes in this area could lead to underestimating the likelihood of encountering an exceptionally hard instance. For analyses of this type, the survival function $S$ is a useful tool; if $F$ is the cdf, $S(x) := 1 − F (x)$. Therefore, the survival function’s value $S(x)$ represents the probability that an instance is (on average) harder than $x$ in our case. If we plot the empirical survival function ($1 − \hat{F}_n (x)$) and the fitted survival function together on a graph with logarithmically scaled axes, we can easily detect errors in the right tail.

# %%
# Select the number of instances to interate over...
N = len(instances)

# ... and iterate over all instances to generate the plots.
for index in range(N):
    #
    # Selection of a concrete instance and name printing
    #
    name = instances[index]
    
    print("*" * (len(name) + len(str(index)) + 3))
    print(index, ":", name)
    print("*" * (len(name) + len(str(index)) + 3))   

    #
    # Manipulate the corresponding data frame:
    # We are only interested in the flip-values, not in the runtime, or seed used.
    #
    df = pd.read_csv(name, index_col=[0,1])
    df.drop(index=['seed', 'runtime'], level=1, inplace=True)

    # Checks if any values are nan.
    if df.isnull().values.any():
        print("There is a nan-value. This was not supposed to happen.")
        
    # Next, we are going to calculate $\mathsf{mean}_{S} (F^{(i)})$,
    # i.e., the mean number of flips required to solve instance $F^{(i)}$ with solver $S$.
    # This then is the hardness distribution we are going to analyze.    
    means = df.mean(axis=1)
    means = np.sort(means)  
        
    #
    # Print the plots with location parameter
    #    
    
    # Scipy can be used to fit a location parameter. 
    # In practise, however, this does not work properly.
    # Thus, we use our own method `SB_minimize_nnlf` 
    # that can be found in the `empirical` package.
    # This method must be provided with the data object `means`, 
    # a lower bound for the location parameter, here `0.0`,
    # and an upper bound for the location parameter, here `means[0]-0.0001`.
    # This method then yields a location parameter maximizing the likelihood.
    m = SB_minimize_nnlf(means, 0.0, means[0]-0.0001)
    means_SB = means - m 

    # Next, we fit a three-parametric Johnson SB distribution 
    # (with forced location parameter zero). Note that means = means - m. 
    # Note that fitting a three-parametric lognormal distribution to 
    # original_data - m is the same as fitting 
    # a four-parametric lognormal distribution to the original_data.
    # Afterwards, we can use our own location parameter.
    a, b, loc, scale = johnsonsb.fit(means_SB, floc=0) # NEW!!!

    print(f"Johnson SB parameters: a {a}, b {b}, location {m}, scale {scale}")
    print(f"Cheng parametrization: a {m}, b {scale+m}, gamma {a}, delta {b}")

    rv_SB = johnsonsb(a, b, loc, scale)
    
    plot_and_compare_cdf(means_SB, rv_SB, suptitle='Johnson SB', plot_confidence=True)

    plt.show(block=False)
    
    print("\n")
# Out:
# ******************************************************************************************************
# 0 : ../../experiments/csvs_factoring/n146/factor_seed5748459585663058586_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 8.386475712418191, b 1.5434226051362119, location 324295.5785151213, scale 2956310235.791967
# Cheng parametrization: a 324295.5785151213, b 2956634531.370482, gamma 8.386475712418191, delta 1.5434226051362119
# ******************************************************************************************************
# 1 : ../../experiments/csvs_factoring/n146/factor_seed6407482039203833974_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 6.6297492225316645, b 1.6958157388065773, location 3.841611773821509e-05, scale 9285284512.02721
# Cheng parametrization: a 3.841611773821509e-05, b 9285284512.027248, gamma 6.6297492225316645, delta 1.6958157388065773
# ******************************************************************************************************
# 2 : ../../experiments/csvs_factoring/n146/factor_seed2982912307005450882_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 8.937278709307563, b 1.6785045997498518, location 417546.9936446955, scale 22256517416.038727
# Cheng parametrization: a 417546.9936446955, b 22256934963.03237, gamma 8.937278709307563, delta 1.6785045997498518
# ******************************************************************************************************
# 3 : ../../experiments/csvs_factoring/n146/factor_seed8811850223749535532_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 11.020764088769681, b 2.0291453727244972, location 916600.6634634135, scale 2957298381.6663933
# Cheng parametrization: a 916600.6634634135, b 2958214982.329857, gamma 11.020764088769681, delta 2.0291453727244972
# ******************************************************************************************************
# 4 : ../../experiments/csvs_factoring/n146/factor_seed7097131721234373659_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 4.417400978023322, b 1.2675260551095209, location 695508.1801711705, scale 469878794.154122
# Cheng parametrization: a 695508.1801711705, b 470574302.3342932, gamma 4.417400978023322, delta 1.2675260551095209
# ******************************************************************************************************
# 5 : ../../experiments/csvs_factoring/n146/factor_seed4387742571411731982_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 8.21932595980492, b 1.6031085108112761, location 2188932.139919994, scale 30143471578.951355
# Cheng parametrization: a 2188932.139919994, b 30145660511.091274, gamma 8.21932595980492, delta 1.6031085108112761
# ******************************************************************************************************
# 6 : ../../experiments/csvs_factoring/n146/factor_seed5193781827104823697_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 11.671480061756185, b 2.404221137446127, location 123662.28535811722, scale 163791273.9534769
# Cheng parametrization: a 123662.28535811722, b 163914936.23883504, gamma 11.671480061756185, delta 2.404221137446127
# ******************************************************************************************************
# 7 : ../../experiments/csvs_factoring/n146/factor_seed4334240155445824856_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 11.189795672383987, b 2.1392541681428563, location 290047.73471301066, scale 380054390.51705813
# Cheng parametrization: a 290047.73471301066, b 380344438.25177115, gamma 11.189795672383987, delta 2.1392541681428563
# ******************************************************************************************************
# 8 : ../../experiments/csvs_factoring/n146/factor_seed8975071664002667775_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 10.00241724581127, b 1.9544370828406605, location 237203.4186957696, scale 864756235.7344291
# Cheng parametrization: a 237203.4186957696, b 864993439.1531249, gamma 10.00241724581127, delta 1.9544370828406605
# ******************************************************************************************************
# 9 : ../../experiments/csvs_factoring/n146/factor_seed7766064159550827863_minn128_maxn256_composite.csv
# ******************************************************************************************************
# Johnson SB parameters: a 8.514452954711885, b 1.6767567553708513, location 335318.9579416245, scale 573689755.1709623
# Cheng parametrization: a 335318.9579416245, b 574025074.128904, gamma 8.514452954711885, delta 1.6767567553708513
# *******************************************************************************************************
# 10 : ../../experiments/csvs_factoring/n146/factor_seed4336985158444443336_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 10.767047305119256, b 2.2581896369735315, location 41591.68572991276, scale 54365701.25304587
# Cheng parametrization: a 41591.68572991276, b 54407292.938775785, gamma 10.767047305119256, delta 2.2581896369735315
# *******************************************************************************************************
# 11 : ../../experiments/csvs_factoring/n146/factor_seed1708947292090439414_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 9.977669019343594, b 1.9343287226092478, location 769277.8154188691, scale 1116973309.0036848
# Cheng parametrization: a 769277.8154188691, b 1117742586.8191037, gamma 9.977669019343594, delta 1.9343287226092478
# *******************************************************************************************************
# 12 : ../../experiments/csvs_factoring/n146/factor_seed8317433272424785325_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 9.234984255371053, b 1.734947978913679, location 3045114.822317068, scale 20902140264.085648
# Cheng parametrization: a 3045114.822317068, b 20905185378.907963, gamma 9.234984255371053, delta 1.734947978913679
# *******************************************************************************************************
# 13 : ../../experiments/csvs_factoring/n146/factor_seed4036333616503776890_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 11.001733290415999, b 2.2568576246293945, location 87051.95098029733, scale 123726050.14469361
# Cheng parametrization: a 87051.95098029733, b 123813102.0956739, gamma 11.001733290415999, delta 2.2568576246293945
# *******************************************************************************************************
# 14 : ../../experiments/csvs_factoring/n146/factor_seed3276133011702650363_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 8.941523682994877, b 2.0553058558409325, location 186476.26615812807, scale 969555621.5108869
# Cheng parametrization: a 186476.26615812807, b 969742097.777045, gamma 8.941523682994877, delta 2.0553058558409325
# *******************************************************************************************************
# 15 : ../../experiments/csvs_factoring/n146/factor_seed5418786872277260423_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 10.791016164431657, b 2.157965405810705, location 146220.6097776714, scale 861137342.7887201
# Cheng parametrization: a 146220.6097776714, b 861283563.3984978, gamma 10.791016164431657, delta 2.157965405810705
# *******************************************************************************************************
# 16 : ../../experiments/csvs_factoring/n146/factor_seed2578686028862375251_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 8.724772033764964, b 2.095392030429668, location 141576.10503837152, scale 136720411.2718854
# Cheng parametrization: a 141576.10503837152, b 136861987.37692377, gamma 8.724772033764964, delta 2.095392030429668
# *******************************************************************************************************
# 17 : ../../experiments/csvs_factoring/n146/factor_seed4058983540373604130_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 10.992294245195499, b 1.9910807036487412, location 152192.924991708, scale 373951892.90463555
# Cheng parametrization: a 152192.924991708, b 374104085.8296273, gamma 10.992294245195499, delta 1.9910807036487412
# *******************************************************************************************************
# 18 : ../../experiments/csvs_factoring/n146/factor_seed3159482308856066977_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 7.42571283940212, b 1.5136436429201994, location 910924.3755655484, scale 2055245913.911974
# Cheng parametrization: a 910924.3755655484, b 2056156838.2875395, gamma 7.42571283940212, delta 1.5136436429201994
# *******************************************************************************************************
# 19 : ../../experiments/csvs_factoring/n146/factor_seed3382895559700741256_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 8.301773329163606, b 1.702944897155632, location 1066214.4549603728, scale 39649697073.22211
# Cheng parametrization: a 1066214.4549603728, b 39650763287.67707, gamma 8.301773329163606, delta 1.702944897155632
# *******************************************************************************************************
# 20 : ../../experiments/csvs_factoring/n146/factor_seed6693062327952490429_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 4.780518451559033, b 1.5872525065968714, location 406823.60629766836, scale 82209704.21679601
# Cheng parametrization: a 406823.60629766836, b 82616527.82309368, gamma 4.780518451559033, delta 1.5872525065968714
# *******************************************************************************************************
# 21 : ../../experiments/csvs_factoring/n146/factor_seed1440291489233318306_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 13.707013253514454, b 2.9022047851585437, location 15875.894227973353, scale 72037297.55608755
# Cheng parametrization: a 15875.894227973353, b 72053173.45031552, gamma 13.707013253514454, delta 2.9022047851585437
# *******************************************************************************************************
# 22 : ../../experiments/csvs_factoring/n146/factor_seed4781976350427207108_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 13.983560004362474, b 2.9301841913824784, location 54725.14190201, scale 151109387.75221848
# Cheng parametrization: a 54725.14190201, b 151164112.89412048, gamma 13.983560004362474, delta 2.9301841913824784
# *******************************************************************************************************
# 23 : ../../experiments/csvs_factoring/n146/factor_seed7560604667037574268_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 7.306863892501374, b 1.6631885372268038, location 0.00028263878931750403, scale 71416160804.78867
# Cheng parametrization: a 0.00028263878931750403, b 71416160804.78896, gamma 7.306863892501374, delta 1.6631885372268038
# *******************************************************************************************************
# 24 : ../../experiments/csvs_factoring/n146/factor_seed3924672928578402759_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 7.385619739265417, b 1.404708353140375, location 296025.00994291366, scale 2260649815.2598867
# Cheng parametrization: a 296025.00994291366, b 2260945840.2698298, gamma 7.385619739265417, delta 1.404708353140375
# *******************************************************************************************************
# 25 : ../../experiments/csvs_factoring/n146/factor_seed3451321871718893577_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 10.492444902302601, b 1.7788621047842792, location 334693.43572785886, scale 1202469496.3598099
# Cheng parametrization: a 334693.43572785886, b 1202804189.7955377, gamma 10.492444902302601, delta 1.7788621047842792
# *******************************************************************************************************
# 26 : ../../experiments/csvs_factoring/n146/factor_seed3101904018255215309_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 11.313109017802702, b 2.4793191547010602, location 534922.1017361969, scale 433900745.983096
# Cheng parametrization: a 534922.1017361969, b 434435668.0848322, gamma 11.313109017802702, delta 2.4793191547010602
# *******************************************************************************************************
# 27 : ../../experiments/csvs_factoring/n146/factor_seed3844218716737448635_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 11.896173079456474, b 2.4255002364716542, location 108292.43833854013, scale 135092760.83223742
# Cheng parametrization: a 108292.43833854013, b 135201053.27057597, gamma 11.896173079456474, delta 2.4255002364716542
# *******************************************************************************************************
# 28 : ../../experiments/csvs_factoring/n146/factor_seed3358904958101883040_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 10.38960577983838, b 2.1879526388811303, location 187352.8109612634, scale 246232611.49429417
# Cheng parametrization: a 187352.8109612634, b 246419964.30525544, gamma 10.38960577983838, delta 2.1879526388811303
# *******************************************************************************************************
# 29 : ../../experiments/csvs_factoring/n146/factor_seed6875843913543011199_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 9.182677791855898, b 2.000105256479535, location 883761.3683667221, scale 1590629896.5634089
# Cheng parametrization: a 883761.3683667221, b 1591513657.9317756, gamma 9.182677791855898, delta 2.000105256479535
# *******************************************************************************************************
# 30 : ../../experiments/csvs_factoring/n146/factor_seed4017489231758302290_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 12.019564857740704, b 2.6253541957930304, location 206879.17838415102, scale 414809476.9242432
# Cheng parametrization: a 206879.17838415102, b 415016356.10262734, gamma 12.019564857740704, delta 2.6253541957930304
# *******************************************************************************************************
# 31 : ../../experiments/csvs_factoring/n146/factor_seed6130376794532478281_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 9.74925357633159, b 1.8013129237866954, location 84891.03723501369, scale 115638764.45593798
# Cheng parametrization: a 84891.03723501369, b 115723655.49317299, gamma 9.74925357633159, delta 1.8013129237866954
# *******************************************************************************************************
# 32 : ../../experiments/csvs_factoring/n146/factor_seed3506515261408426867_minn128_maxn256_composite.csv
# *******************************************************************************************************
# Johnson SB parameters: a 9.61965770111091, b 1.678895139515232, location 989473.3106809433, scale 55533537315.52803
# Cheng parametrization: a 989473.3106809433, b 55534526788.838715, gamma 9.61965770111091, delta 1.678895139515232

# %% [markdown]
# ## Statistical Tests
#
# As described in the paper, we use a statistical test to check the goodness-of-fit.
#
# (The p-values obtained were calculated seperately and can be found in `./evaluation/evaluate_SB/all_tests.csv` for all solver and instance combinations. The reason for this is that it takes several hours to compute these values because of the bootstrapping.)

# %%
# Use the instance list as a selector for the correct rows in the `all_tests.csv` file.
selector = [path.split('../../experiments/')[1] for path in instances]
selector

# Extract the relevant rows from the data frame.
file = '../evaluate_SB/all_tests.csv'
df = pd.read_csv(file, index_col=False)
df = df[df['instance'].isin(selector)]

# Sort the entries to match the order of the diagrams above.
df['instance'] = pd.Categorical(
    df['instance'], 
    categories=selector, 
    ordered=True
)
df.sort_values('instance', inplace=True)

# Show the instance name without path
df['instance'] = df['instance'].map(lambda name: name.split("/")[-1].split(".csv")[0])

# Mark entries where the tests failes
stars = np.where((df['p_orig']<0.05) & (df['p_new']<0.05), 'rejected', ' ')
df.loc[:, 'rejected'] = stars.tolist()

# Add the index we used
index = list(range(len(instances)))
df['index'] = index

# Change order of columns s.th. index is the first one
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

df
# Out:
#      index  type                                           instance    p_orig  \
# 152      0  SRWA  factor_seed5748459585663058586_minn128_maxn256...  0.697784
# 153      1  SRWA  factor_seed6407482039203833974_minn128_maxn256...  0.996129
# 154      2  SRWA  factor_seed2982912307005450882_minn128_maxn256...  0.313278
# 155      3  SRWA  factor_seed8811850223749535532_minn128_maxn256...  0.558341
# 156      4  SRWA  factor_seed7097131721234373659_minn128_maxn256...  0.159800
# 157      5  SRWA  factor_seed4387742571411731982_minn128_maxn256...  0.116060
# 158      6  SRWA  factor_seed5193781827104823697_minn128_maxn256...  0.766739
# 159      7  SRWA  factor_seed4334240155445824856_minn128_maxn256...  0.114378
# 160      8  SRWA  factor_seed8975071664002667775_minn128_maxn256...  0.561893
# 161      9  SRWA  factor_seed7766064159550827863_minn128_maxn256...  0.135757
# 162     10  SRWA  factor_seed4336985158444443336_minn128_maxn256...  0.256535
# 163     11  SRWA  factor_seed1708947292090439414_minn128_maxn256...  0.149454
# 164     12  SRWA  factor_seed8317433272424785325_minn128_maxn256...  0.861594
# 165     13  SRWA  factor_seed4036333616503776890_minn128_maxn256...  0.186557
# 166     14  SRWA  factor_seed3276133011702650363_minn128_maxn256...  0.135757
# 167     15  SRWA  factor_seed5418786872277260423_minn128_maxn256...  0.229079
# 168     16  SRWA  factor_seed2578686028862375251_minn128_maxn256...  0.547663
# 169     17  SRWA  factor_seed4058983540373604130_minn128_maxn256...  0.259376
# 170     18  SRWA  factor_seed3159482308856066977_minn128_maxn256...  0.405849
# 171     19  SRWA  factor_seed3382895559700741256_minn128_maxn256...  0.607602
# 172     20  SRWA  factor_seed6693062327952490429_minn128_maxn256...  0.216020
# 173     21  SRWA  factor_seed1440291489233318306_minn128_maxn256...  0.058784
# 174     22  SRWA  factor_seed4781976350427207108_minn128_maxn256...  0.234429
# 175     23  SRWA  factor_seed7560604667037574268_minn128_maxn256...  0.253711
# 176     24  SRWA  factor_seed3924672928578402759_minn128_maxn256...  0.056804
# 177     25  SRWA  factor_seed3451321871718893577_minn128_maxn256...  0.877324
# 178     26  SRWA  factor_seed3101904018255215309_minn128_maxn256...  0.270908
# 179     27  SRWA  factor_seed3844218716737448635_minn128_maxn256...  0.310153
# 180     28  SRWA  factor_seed3358904958101883040_minn128_maxn256...  0.775071
# 181     29  SRWA  factor_seed6875843913543011199_minn128_maxn256...  0.734832
# 182     30  SRWA  factor_seed4017489231758302290_minn128_maxn256...  0.926590
# 183     31  SRWA  factor_seed6130376794532478281_minn128_maxn256...  0.934109
# 184     32  SRWA  factor_seed3506515261408426867_minn128_maxn256...  0.151486
#
#      p_new rejected
# 152   0.70
# 153   0.99
# 154   0.34
# 155   0.51
# 156   0.16
# 157   0.11
# 158   0.73
# 159   0.06
# 160   0.57
# 161   0.17
# 162   0.23
# 163   0.11
# 164   0.89
# 165   0.18
# 166   0.13
# 167   0.22
# 168   0.47
# 169   0.33
# 170   0.41
# 171   0.59
# 172   0.26
# 173   0.09
# 174   0.25
# 175   0.29
# 176   0.08
# 177   0.80
# 178   0.23
# 179   0.21
# 180   0.72
# 181   0.64
# 182   0.96
# 183   0.95
# 184   0.09
